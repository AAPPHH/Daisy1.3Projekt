# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"game_history.xlsx"
data = pd.read_excel(file_path)

# %%
data['winner'] = pd.Categorical(data['winner'])

# Plotten
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='N_turn', y='winner', palette='deep')

plt.title('Scatter Plot of Game Winner vs Number of Turns')
plt.xlabel('Number of Turns (N_turn)')
plt.ylabel('Winner')

plt.show()
# Out:
# c:\Users\jfham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\jfham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jfham\AppData\Local\Temp\ipykernel_32552\1643305666.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=data, x='N_turn', y='winner', palette='deep')
